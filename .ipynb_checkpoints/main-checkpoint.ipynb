# %% [markdown]
# ## 1. Import text and stop words

# %%
#Specify path to input and output directories
input_dir = '/Users/dankoban/Documents/EM6575/LDAInput'
output_dir = '/Users/dankoban/Documents/EM6575/LDAOutput'

# %%
import os
import pandas as pd
from concurrent.futures import ThreadPoolExecutor
from tqdm import tqdm
import time
from datetime import timedelta

def read_crowdtangle_file(file):    
    df = pd.read_csv(file, dtype='unicode')
    """Extract and clean text fields from a Crowd Tangle Data File."""
    # Extract text from all fields with text
    df['Text']= df['Message'].map(str) + ' '     \
                + df['Image Text'].map(str)+ ' ' \
                + df['Link Text'].map(str) + ' ' \
                + df['Description'].map(str)
    
    # Remove extraneous characters
    df['Text'] = (df['Text'].str.replace('nan',' ')
                            .str.replace('\n',' ')
                            .str.replace('\r',' ')
                            .str.replace(r"http\S+",' '))
                            #.str.decode('ascii','ignore')
    df = df[['Facebook Id','Text']]
    return df

def read_crowdtangle_files(file_paths):
    """Read multiple csv files using multi-threading."""
    with ThreadPoolExecutor() as executor:
        with tqdm(total = len(file_paths)) as progress:
            futures = []
            for file in file_paths:
                future = executor.submit(read_crowdtangle_file, file)
                future.add_done_callback(lambda p: progress.update())
                futures.append(future)
            results = []
            for future in futures:
                result = future.result()
                results.append(result)
            return(results)

# Extract file names from input directory
files = [file for file in os.listdir(input_dir) if file.endswith(".csv")]   
file_paths = [input_dir + "/" + file for file in files]

# Select only n files for testing
file_paths = file_paths[0:2]

start_time = time.time()
df = read_crowdtangle_files(file_paths)
print("--- %s time elapsed ---" % str(timedelta(seconds=time.time() - start_time)))
# Out:
# 100%|██████████| 2/2 [00:05<00:00,  2.95s/it]
# --- 0:00:05.927654 time elapsed ---

# %%
df = pd.concat(df)
df = df.head(10000)
print(len(df))
df.head()
# Out:
# 10000
#        Facebook Id                                               Text
# 0  624614494274945  Nika Vetsko, excerpts: ...Many researchers bel...
# 1      26781952138  The capital’s first Covid-19 patient, a 45-yea...
# 2     251907774312  The coronavirus pandemic is yet to force wides...
# 3  138280549589759  The safety and well-being of our community and...
# 4      32204506174  With the coronavirus spreading across the glob...

# %%
# Stop words from Box
stop_words = pd.read_csv("/Users/dankoban/Documents/CT_LDA/new_stopwords.csv")
stop_words = stop_words['stop_word'].tolist()
stop_words[0:5]
# Out:
# ['a', 'able', 'about', 'above', 'according']

# %% [markdown]
# ## 2. Fit an LDA model using gensim LdaMallet

# %%
from gensim.models.wrappers import LdaMallet
from sklearn.feature_extraction.text import CountVectorizer 
from gensim import corpora, models, matutils
from gensim.test.utils import datapath
os.environ.update({'MALLET_HOME':r'/Users/dankoban/mallet-2.0.8/'})

vectorizer = CountVectorizer(stop_words=stop_words, 
                             ngram_range = (1,2), 
                             token_pattern="\\b[a-z][a-z][a-z]+\\b") 
vectorizer.fit(df.Text)
doc_word = vectorizer.transform(df.Text).transpose()
corpus = matutils.Sparse2Corpus(doc_word)

word2id = dict((v, k) for v, k in vectorizer.vocabulary_.items())
id2word = dict((v, k) for k, v in vectorizer.vocabulary_.items())

dictionary = corpora.Dictionary()
dictionary.id2token = id2word
dictionary.token2id = word2id
dictionary.filter_extremes(no_below=5, no_above=0.95)

# creating the LDA model
train_model_flag = True  # True, if want to create a new model, False, if loading the existing model

start_time = time.time()
if train_model_flag:
    lda = LdaMallet(mallet_path = '/Users/dankoban/mallet-2.0.8/bin/mallet', 
                    corpus=corpus, num_topics=50, id2word=id2word, 
                    workers = 7, random_seed = 1)

    # Save model to disk
    model_file = datapath("crowdtangle.model")
    lda.save(model_file)
else:
    # Load the pretrained model from disk
    pass
    #lda = LdaModel.load(temp_file)

print("--- %s time elapsed ---" % str(timedelta(seconds=time.time() - start_time)))
# Out:
# /Users/dankoban/Documents/workspace/python/venvs/forcenexus/lib/python3.8/site-packages/sklearn/feature_extraction/text.py:383: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['don', 'dont', 'hey', 'ive', 'lets', 'weve', 'yall', 'youd', 'youre'] not in stop_words.
#   warnings.warn('Your stop_words may be inconsistent with '
# --- 0:00:59.005696 time elapsed ---

# %%
from pprint import pprint
# Show Topics
pprint(lda.show_topic(1))
# Out:
# [('coronavirus', 0.1009504111882602),
#  ('link', 0.029103264884030138),
#  ('video', 0.027281233072339588),
#  ('read', 0.023489437139902498),
#  ('watch', 0.021273452504062637),
#  ('full', 0.01831880632294283),
#  ('story', 0.01723543605653223),
#  ('click', 0.015511892450879007),
#  ('tom', 0.011818584724479244),
#  ('online', 0.011326143694292608)]

# %% [markdown]
# ## 3. Organize the topics into a format that is easy to read

# %%
tm_results = lda[corpus]
corpus_topics = [sorted(topics, 
                        key=lambda record: -record[1])[0] for topics in tm_results]

topics = [[(term, round(wt, 3)) for term, wt in lda.show_topic(n, topn=20)] \
                                for n in range(0, lda.num_topics)]

topics_df = pd.DataFrame([[term for term, wt in topic] for topic in topics], 
                         columns = ['Term'+str(i) for i in range(1, 21)], 
                         index=['Topic '+str(t) for t in range(1, lda.num_topics+1)]).T
topics_df
# Out:
#              Topic 1      Topic 2      Topic 3        Topic 4      Topic 5  \
# Term1          hours  coronavirus         city           list     outbreak
# Term2         stores         link        mayor           stop         amid
# Term3        walmart        video         town    coronavirus  coronavirus
# Term4          store         read  coronavirus        growing          man
# Term5    coronavirus        watch         long           area     distance
# Term6         sunday         full    residents         effort        giant
# Term7           open        story         york          shows     measures
# Term8       starting        click        beach          covid       people
# Term9        grocery          tom         hall       canceled      drastic
# Term10        notice       online         full        classes         safe
# Term11     locations      article   quarantine        related         call
# Term12     operating        james        urged          stage        times
# Term13           cut        hanks        today       concerts        order
# Term14      response     complete        fight      festivals       market
# Term15      changing      warning        march  cancellations        italy
# Term16       shelves    resources      teaneck        parades         arts
# Term17          hour       center       spread           bike      wearing
# Term18    nationwide       movies        urges          rides         rome
# Term19  neighborhood       taiwan    officials          proms       skills
# Term20           due       shares      manager         events     employed
#
#           Topic 6       Topic 7      Topic 8      Topic 9     Topic 10  ...  \
# Term1       march     cancelled        virus  coronavirus  coronavirus  ...
# Term2      public        events       people         live          day  ...
# Term3      center        season     infected    questions     concerns  ...
# Term4      closed           due       corona      officer         mass  ...
# Term5    services         event          flu        chief      weekend  ...
# Term6      remain         march     symptoms      medical      patrick  ...
# Term7   effective      decision      doctors   healthcare       parade  ...
# Term8        open     scheduled    infection      meeting   gatherings  ...
# Term9      monday     postponed     patients      special       masses  ...
# Term10     notice         april  coronavirus      experts       annual  ...
# Term11   continue  cancellation       deadly       follow     catholic  ...
# Term12       city          date         rate      options   restaurant  ...
# Term13  community          show         care       cities          nyc  ...
# Term14     office         music      elderly       answer         week  ...
# Term15    library      festival      disease    including     churches  ...
# Term16  suspended       tickets       deaths  communities       cancel  ...
# Term17     county         place         kill    potential       parish  ...
# Term18     senior        cancel      vaccine      discuss     canceled  ...
# Term19     events     committee       nurses        board        close  ...
# Term20      phone          time   vulnerable       office      diocese  ...
#
#            Topic 41     Topic 42     Topic 43     Topic 44  Topic 45  \
# Term1   coronavirus  coronavirus  coronavirus       advice     hands
# Term2        states       threat       cruise  coronavirus     covid
# Term3        united        group        virus         good  symptoms
# Term4         death       system  quarantined          don   contact
# Term5          year       immune         ship         tips     avoid
# Term6         covid       friday   passengers      feeling      sick
# Term7           man          day         home         time    people
# Term8        oregon        fight        surge     medicine      wash
# Term9        caused     strategy   quarantine         make      home
# Term10       health         body     handling         deal     water
# Term11       person        times        grand        drink     cough
# Term12        woman  independent     princess          isn      risk
# Term13      reports      nations         lack         lots    health
# Term14         died        saarc      network         huge      soap
# Term15       county         held     multiple         hear     fever
# Term16         toll      systems    attention         meds     virus
# Term17     employee     immunity      netflix         days      stay
# Term18    authority        today       couple         home      hand
# Term19    multnomah        video      medical        worth    spread
# Term20       deaths      focused        creek         rest     close
#
#            Topic 46     Topic 47        Topic 48  Topic 49       Topic 50
# Term1         paper       safety           trump       god         travel
# Term2        toilet     continue          tested    prayer          india
# Term3          hand         safe       president      pray            ban
# Term4     sanitizer     cleaning        positive      lord      countries
# Term5        people         team     coronavirus     jesus   restrictions
# Term6         price        staff           tests     faith        flights
# Term7         items       taking        negative      fear    coronavirus
# Term8           ang          flu            test    christ           iran
# Term9        buying       family           house      time         flight
# Term10     supplies         cold          donald       day        ireland
# Term11          mga      members           white     peace         canada
# Term12      gouging  precautions         results  national         indian
# Term13        panic       ensure          doctor      love  international
# Term14        masks    employees       physician     world            air
# Term15      bottles         stay        saturday    people         europe
# Term16         sell     priority           virus     times        foreign
# Term17  coronavirus     symptoms  administration      life     government
# Term18       amazon    situation      washington    nation       european
# Term19      stocked    customers        personal     power        tourism
# Term20     hundreds         hand           night    wisdom       domestic
#
# [20 rows x 50 columns]

# %%
# set column width
pd.set_option('display.max_colwidth', None)
topics_df = pd.DataFrame([', '.join([term for term, wt in topic]) for topic in topics], 
                         columns = ['Terms per Topic'], 
                         index=['Topic'+str(t) for t in range(1, lda.num_topics+1)] )
topics_df
# Out:
#                                                                                                                                                                                   Terms per Topic
# Topic1           hours, stores, walmart, store, coronavirus, sunday, open, starting, grocery, notice, locations, operating, cut, response, changing, shelves, hour, nationwide, neighborhood, due
# Topic2                                coronavirus, link, video, read, watch, full, story, click, tom, online, article, james, hanks, complete, warning, resources, center, movies, taiwan, shares
# Topic3                               city, mayor, town, coronavirus, long, residents, york, beach, hall, full, quarantine, urged, today, fight, march, teaneck, spread, urges, officials, manager
# Topic4                   list, stop, coronavirus, growing, area, effort, shows, covid, canceled, classes, related, stage, concerts, festivals, cancellations, parades, bike, rides, proms, events
# Topic5                               outbreak, amid, coronavirus, man, distance, giant, measures, people, drastic, safe, call, times, order, market, italy, arts, wearing, rome, skills, employed
# Topic6                     march, public, center, closed, services, remain, effective, open, monday, notice, continue, city, community, office, library, suspended, county, senior, events, phone
# Topic31                     pandemic, coronavirus, world, crisis, global, sports, organization, economy, year, week, response, fight, basketball, major, face, end, nation, bit, empty, singapore
# Topic32                                              coronavirus, biden, age, years, expert, good, face, die, joe, viral, campaign, air, perfect, anti, fyi, effective, post, masks, thinks, hong
# Topic33                                                  time, share, make, things, friends, post, important, love, give, find, don, safe, change, lot, making, coming, thing, family, good, feel
# Topic34              spread, coronavirus, number, prevent, reduce, slow, percent, leaders, casinos, patrons, allowed, facilities, continues, maryland, stem, limit, rise, prompts, women, attempt
# Topic35            local, businesses, business, support, small, impact, time, impacted, ways, economic, club, helping, unprecedented, communities, world, disaster, rotary, post, industry, share
# Topic36                   social, distancing, public, people, stay, health, home, media, part, gatherings, family, practice, san, means, contact, individual, system, today, staying, coronavirus
# Topic37                   school, schools, students, closures, district, closed, monday, march, college, staff, online, week, closings, spring, children, student, parents, classes, weeks, close
# Topic38            state, governor, order, gov, department, north, emergency, federal, executive, california, public, issued, covid, court, response, resources, friday, dakota, action, carolina
# Topic39     covid, measures, members, message, continued, ministry, training, entry, personnel, persons, guard, march, additional, precautionary, provided, service, army, force, nelson, mission
# Topic40                               church, sunday, services, tomorrow, worship, service, facebook, online, join, stay, live, pastor, family, home, march, morning, love, community, page, time
# Topic41                          coronavirus, states, united, death, year, covid, man, oregon, caused, health, person, woman, reports, died, county, toll, employee, authority, multnomah, deaths
# Topic42                        coronavirus, threat, group, system, immune, friday, day, fight, strategy, body, times, independent, nations, saarc, held, systems, immunity, today, video, focused
# Topic43        coronavirus, cruise, virus, quarantined, ship, passengers, home, surge, quarantine, handling, grand, princess, lack, network, multiple, attention, netflix, couple, medical, creek
# Topic44                                                    advice, coronavirus, good, don, tips, feeling, time, medicine, make, deal, drink, isn, lots, huge, hear, meds, days, home, worth, rest
# Topic45                                               hands, covid, symptoms, contact, avoid, sick, people, wash, home, water, cough, risk, health, soap, fever, virus, stay, hand, spread, close
# Topic46                            paper, toilet, hand, sanitizer, people, price, items, ang, buying, supplies, mga, gouging, panic, masks, bottles, sell, coronavirus, amazon, stocked, hundreds
# Topic47                   safety, continue, safe, cleaning, team, staff, taking, flu, family, cold, members, precautions, ensure, employees, stay, priority, symptoms, situation, customers, hand
# Topic48    trump, tested, president, positive, coronavirus, tests, negative, test, house, donald, white, results, doctor, physician, saturday, virus, administration, washington, personal, night
# Topic49                                                  god, prayer, pray, lord, jesus, faith, fear, christ, time, day, peace, national, love, world, people, times, life, nation, power, wisdom
# Topic50    travel, india, ban, countries, restrictions, flights, coronavirus, iran, flight, ireland, canada, indian, international, air, europe, foreign, government, european, tourism, domestic

# %% [markdown]
# ## 4. Visualize topics with a clustermap

# %%
from collections import OrderedDict
data_lda = {i: OrderedDict(lda.show_topic(i,5)) for i in range(50)}
df_lda = pd.DataFrame(data_lda)
df_lda = df_lda.fillna(0).T
print(df_lda.shape)
# Out:
# (50, 196)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
g=sns.clustermap(df_lda.corr(), center=0, standard_scale=1, 
                 cmap="RdBu", metric='cosine', linewidths=.75, figsize=(15, 15))
plt.setp(g.ax_heatmap.yaxis.get_majorticklabels(), rotation=0)
plt.show()
# Out:
# /Users/dankoban/Documents/workspace/python/venvs/forcenexus/lib/python3.8/site-packages/seaborn/matrix.py:649: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)
